# %%
import pandas as pd

# %% [markdown]
# ................Importing data set.............

# %%
data=pd.read_csv("D:/New folder/loan_predict/loan_approval_dataset.csv")

# %%
data.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                 2          1              1       9600000     29900000
# 1                 0          0              0       4100000     12200000
# 2                 3          1              1       9100000     29700000
# 3                 3          1              1       8200000     30700000
# 4                 5          0              0       9800000     24200000
#
#    loan_term  cibil_score  loan_status    Assets
# 0         12          778            1  50700000
# 1          8          417            0  17000000
# 2         20          506            0  57700000
# 3          8          467            0  52700000
# 4         20          382            0  55000000

# %% [raw]
# ..........Dropping unwanted loan_id............

# %%
data.drop(columns=['loan_id'],inplace=True)

# %%
data.columns
# Out:
# Index([' no_of_dependents', ' education', ' self_employed', ' income_annum',
#        ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
data.columns=data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %% [markdown]
# ......... Added assests into one single assests.........

# %%
data['Assets']=data.residential_assets_value+data.commercial_assets_value+data.luxury_assets_value+data.bank_asset_value

# %%
data
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# 1        12200000          8          417                   2700000
# 2        29700000         20          506                   7100000
# 3        30700000          8          467                  18200000
# 4        24200000         20          382                  12400000
# ...           ...        ...          ...                       ...
# 4264      2300000         12          317                   2800000
# 4265     11300000         20          559                   4200000
# 4266     23900000         18          457                   1200000
# 4267     12800000          8          780                   8200000
# 4268     29700000         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#      loan_status    Assets
# 0       Approved  50700000
# 1       Rejected  17000000
# 2       Rejected  57700000
# 3       Rejected  52700000
# 4       Rejected  55000000
# ...          ...       ...
# 4264    Rejected   7400000
# 4265    Approved  20000000
# 4266    Rejected  39000000
# 4267    Approved  28800000
# 4268    Approved  77300000
#
# [4269 rows x 13 columns]

# %%
data.drop(columns=['residential_assets_value','commercial_assets_value','luxury_assets_value','bank_asset_value'])
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              1       9600000     29900000
# 1                    0          0              0       4100000     12200000
# 2                    3          1              1       9100000     29700000
# 3                    3          1              1       8200000     30700000
# 4                    5          0              0       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              0       1000000      2300000
# 4265                 0          0              0       3300000     11300000
# 4266                 2          0              1       6500000     23900000
# 4267                 1          0              1       4100000     12800000
# 4268                 1          1              1       9200000     29700000
#
#       loan_term  cibil_score  loan_status    Assets
# 0            12          778            1  50700000
# 1             8          417            0  17000000
# 2            20          506            0  57700000
# 3             8          467            0  52700000
# 4            20          382            0  55000000
# ...         ...          ...          ...       ...
# 4264         12          317            0   7400000
# 4265         20          559            1  20000000
# 4266         18          457            0  39000000
# 4267          8          780            1  28800000
# 4268         10          607            1  77300000
#
# [4269 rows x 9 columns]

# %%
data.education.unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
def clean_data(st):
    st=st.strip()
    return st;

# %%
clean_data(' Graduate')
# Out:
# 'Graduate'

# %%
data.education=data.education.apply(clean_data)

# %% [raw]
# ..... Replacing with 1 and 0........

# %%
data.education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
data['education']=data['education'].replace(['Graduate','Not Graduate'],[1,0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13852\727335908.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['education']=data['education'].replace(['Graduate','Not Graduate'],[1,0])

# %%
data
# Out:
#       no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                    2          1            No       9600000     29900000
# 1                    0          0           Yes       4100000     12200000
# 2                    3          1            No       9100000     29700000
# 3                    3          1            No       8200000     30700000
# 4                    5          0           Yes       9800000     24200000
# ...                ...        ...           ...           ...          ...
# 4264                 5          1           Yes       1000000      2300000
# 4265                 0          0           Yes       3300000     11300000
# 4266                 2          0            No       6500000     23900000
# 4267                 1          0            No       4100000     12800000
# 4268                 1          1            No       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# 1             8          417                   2700000
# 2            20          506                   7100000
# 3             8          467                  18200000
# 4            20          382                  12400000
# ...         ...          ...                       ...
# 4264         12          317                   2800000
# 4265         20          559                   4200000
# 4266         18          457                   1200000
# 4267          8          780                   8200000
# 4268         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#      loan_status    Assets
# 0       Approved  50700000
# 1       Rejected  17000000
# 2       Rejected  57700000
# 3       Rejected  52700000
# 4       Rejected  55000000
# ...          ...       ...
# 4264    Rejected   7400000
# 4265    Approved  20000000
# 4266    Rejected  39000000
# 4267    Approved  28800000
# 4268    Approved  77300000
#
# [4269 rows x 13 columns]

# %%
data.self_employed.unique()
# Out:
# array([' No', ' Yes'], dtype=object)

# %%
data.self_employed=data.self_employed.apply(clean_data)

# %%
data.self_employed.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['self_employed']=data['self_employed'].replace(['No','Yes'],[1,0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13852\775606179.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['self_employed']=data['self_employed'].replace(['No','Yes'],[1,0])

# %%
data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              1       9600000     29900000
# 1                    0          0              0       4100000     12200000
# 2                    3          1              1       9100000     29700000
# 3                    3          1              1       8200000     30700000
# 4                    5          0              0       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              0       1000000      2300000
# 4265                 0          0              0       3300000     11300000
# 4266                 2          0              1       6500000     23900000
# 4267                 1          0              1       4100000     12800000
# 4268                 1          1              1       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# 1             8          417                   2700000
# 2            20          506                   7100000
# 3             8          467                  18200000
# 4            20          382                  12400000
# ...         ...          ...                       ...
# 4264         12          317                   2800000
# 4265         20          559                   4200000
# 4266         18          457                   1200000
# 4267          8          780                   8200000
# 4268         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#      loan_status    Assets
# 0       Approved  50700000
# 1       Rejected  17000000
# 2       Rejected  57700000
# 3       Rejected  52700000
# 4       Rejected  55000000
# ...          ...       ...
# 4264    Rejected   7400000
# 4265    Approved  20000000
# 4266    Rejected  39000000
# 4267    Approved  28800000
# 4268    Approved  77300000
#
# [4269 rows x 13 columns]

# %%
data.loan_status=data.loan_status.apply(clean_data)

# %%
data.loan_status.unique()
# Out:
# array(['Approved', 'Rejected'], dtype=object)

# %%
data['loan_status']=data['loan_status'].replace(['Approved', 'Rejected'],[1,0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13852\939214139.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['loan_status']=data['loan_status'].replace(['Approved', 'Rejected'],[1,0])

# %%
data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              1       9600000     29900000
# 1                    0          0              0       4100000     12200000
# 2                    3          1              1       9100000     29700000
# 3                    3          1              1       8200000     30700000
# 4                    5          0              0       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              0       1000000      2300000
# 4265                 0          0              0       3300000     11300000
# 4266                 2          0              1       6500000     23900000
# 4267                 1          0              1       4100000     12800000
# 4268                 1          1              1       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# 1             8          417                   2700000
# 2            20          506                   7100000
# 3             8          467                  18200000
# 4            20          382                  12400000
# ...         ...          ...                       ...
# 4264         12          317                   2800000
# 4265         20          559                   4200000
# 4266         18          457                   1200000
# 4267          8          780                   8200000
# 4268         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#       loan_status    Assets
# 0               1  50700000
# 1               0  17000000
# 2               0  57700000
# 3               0  52700000
# 4               0  55000000
# ...           ...       ...
# 4264            0   7400000
# 4265            1  20000000
# 4266            0  39000000
# 4267            1  28800000
# 4268            1  77300000
#
# [4269 rows x 13 columns]

# %%
data=data.drop(columns=['residential_assets_value','commercial_assets_value','luxury_assets_value','bank_asset_value'])

# %%
data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              1       9600000     29900000
# 1                    0          0              0       4100000     12200000
# 2                    3          1              1       9100000     29700000
# 3                    3          1              1       8200000     30700000
# 4                    5          0              0       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              0       1000000      2300000
# 4265                 0          0              0       3300000     11300000
# 4266                 2          0              1       6500000     23900000
# 4267                 1          0              1       4100000     12800000
# 4268                 1          1              1       9200000     29700000
#
#       loan_term  cibil_score  loan_status    Assets
# 0            12          778            1  50700000
# 1             8          417            0  17000000
# 2            20          506            0  57700000
# 3             8          467            0  52700000
# 4            20          382            0  55000000
# ...         ...          ...          ...       ...
# 4264         12          317            0   7400000
# 4265         20          559            1  20000000
# 4266         18          457            0  39000000
# 4267          8          780            1  28800000
# 4268         10          607            1  77300000
#
# [4269 rows x 9 columns]

# %% [raw]
# ............splitting training data set and testing data set.........

# %%
from sklearn.model_selection import train_test_split

# %%
input_data=data.drop(columns=['loan_status'])
output_data=data['loan_status']

# %%
input_data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              1       9600000     29900000
# 1                    0          0              0       4100000     12200000
# 2                    3          1              1       9100000     29700000
# 3                    3          1              1       8200000     30700000
# 4                    5          0              0       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              0       1000000      2300000
# 4265                 0          0              0       3300000     11300000
# 4266                 2          0              1       6500000     23900000
# 4267                 1          0              1       4100000     12800000
# 4268                 1          1              1       9200000     29700000
#
#       loan_term  cibil_score    Assets
# 0            12          778  50700000
# 1             8          417  17000000
# 2            20          506  57700000
# 3             8          467  52700000
# 4            20          382  55000000
# ...         ...          ...       ...
# 4264         12          317   7400000
# 4265         20          559  20000000
# 4266         18          457  39000000
# 4267          8          780  28800000
# 4268         10          607  77300000
#
# [4269 rows x 8 columns]

# %%
output_data
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((3415, 8), (854, 8), (3415,), (854,))

# %% [raw]
# Scaling the data to remove outliers

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)

# %%
x_test_scaled=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test_scaled, y_test)
# Out:
# 0.9250585480093677

# %%
data.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'loan_status', 'Assets'],
#       dtype='object')

# %% [raw]
# Predict using sample data

# %%
pred_data=pd.DataFrame( [['3','1','1','9100000','29700000','20','506','57700000']],columns=['no_of_dependents','education','self_employed','income_annum',
       'loan_amount', 'loan_term', 'cibil_score', 'Assets'])

# %%
pred_data
# Out:
#   no_of_dependents education self_employed income_annum loan_amount loan_term  \
# 0                3         1             1      9100000    29700000        20
#
#   cibil_score    Assets
# 0         506  57700000

# %%
model.predict(pred_data)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import pickle as pk

# %%
pk.dump(model,open('model.pkl','wb'))

# %%
pk.dump(scaler,open('scaler.pkl','wb'))
